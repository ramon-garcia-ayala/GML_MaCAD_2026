# %% [markdown]
# # Creating a Semantic Relationships Graph from an IFC file

# %%
# This cell is not needed if you have pip installed topologicpy
import sys
sys.path.append("C:/Users/sarwj/OneDrive - Cardiff University/Documents/GitHub/topologicpy/src")

# %% [markdown]
# ## 1. Import the needed TopologicPy Classes

# %%
from topologicpy.Topology import Topology
from topologicpy.Graph import Graph
from topologicpy.Dictionary import Dictionary
from topologicpy.Helper import Helper
from topologicpy.Color import Color
from topologicpy.IFC import IFC

# %% [markdown]
# ## 2. Check the TopologicPy version

# %%
print("This tutorial requires topologicpy version 0.9.31 or newer.")
print(Helper.Version())
# Out:
# This tutorial requires topologicpy version 0.9.31 or newer.
# The version that you are using (0.9.31) is EQUAL TO the latest version available on PyPI.

# %% [markdown]
# ## 3. Set your renderer:
# * Visual studio code: "vscode"
# * Google Colab: "colab"
# * Browser: "browser"

# %%
renderer = "vscode"

# %% [markdown]
# ## 5. Specify the path to the IFC file and what to include, and path to output .HTML file for PyVis

# %%
# Choose your own IFC file if you wish
ifc_file_path = r"C:\Users\sarwj\OneDrive - Cardiff University\IAAC\2025-26\S3 - Buildings As Graphs\notebooks\Supporting Files\NVW_DCR-LOD100_Arch.ifc"
#ifc_file_path = r"C:\Users\sarwj\OneDrive - Cardiff University\IAAC\2025-26\S3 - Buildings As Graphs\notebooks\Supporting Files\NVW_DCR-LOD200_Arch.ifc"
ifc_file = IFC.FileByPath(ifc_file_path)

pyvis_file_path = r"C:\Users\sarwj\OneDrive - Cardiff University\Desktop\pyvis_graph.html"
# Out:
# IFCFastTopology.Parse - Parsed 3455 entities in 0.077s.

# %% [markdown]
# ## 6. List all the IFC element types found in the IFC file

# %%
element_types = IFC.ElementTypes(ifc_file, includeCounts = False, silent = False)
element_types = [e.lower() for e in element_types]
for element_type in element_types:
    print(element_type)
# Out:
# ifcapplication
# ifcarbitraryclosedprofiledef
# ifcarbitraryprofiledefwithvoids
# ifcaxis2placement3d
# ifcbuilding
# ifcbuildingstorey
# ifccartesianpoint
# ifcclassificationreference
# ifcconnectionsurfacegeometry
# ifcconversionbasedunit
# ifccurveboundedplane
# ifcdimensionalexponents
# ifcdirection
# ifcelementquantity
# ifcextrudedareasolid
# ifcgeometricrepresentationcontext
# ifclocalplacement
# ifcmaterial
# ifcmateriallayer
# ifcmateriallayerset
# ifcmateriallayersetusage
# ifcmeasurewithunit
# ifcorganization
# ifcownerhistory
# ifcperson
# ifcpersonandorganization
# ifcplane
# ifcpolyline
# ifcpostaladdress
# ifcproductdefinitionshape
# ifcproject
# ifcpropertyset
# ifcpropertysinglevalue
# ifcquantityarea
# ifcquantitylength
# ifcrelaggregates
# ifcrelassociatesclassification
# ifcrelassociatesmaterial
# ifcrelcontainedinspatialstructure
# ifcreldefinesbyproperties
# ifcrelspaceboundary
# ifcshaperepresentation
# ifcsite
# ifcsiunit
# ifcslab
# ifcspace
# ifcunitassignment
# ifcvirtualelement

# %% [markdown]
# ## 7. List all the relationship types found in the IFC file

# %%
rel_types = IFC.RelationshipTypes(ifc_file, includeCounts = False, silent = False)
rel_types = [r.lower() for r in rel_types]
for rel_type in rel_types:
    print(rel_type)
# Out:
# ifcrelaggregates
# ifcrelassociatesclassification
# ifcrelassociatesmaterial
# ifcrelcontainedinspatialstructure
# ifcreldefinesbyproperties
# ifcrelspaceboundary

# %% [markdown]
# ## 8. Convert the IFC file to a graph

# %%
graph = Graph.ByIFCPath(ifc_file_path,
                        importMode="topology",
                        dictionaryMode="all",
                        xMin = -5, yMin = -5, zMin = -5,
                        xMax = 5, yMax = 5, zMax = 5,
                        colorScale="twilight"
                       )
print(graph)
print("Vertices:", len(Graph.Vertices(graph)))
print("Edges:", len(Graph.Edges(graph)))
# Out:
# <topologic_core.Graph object at 0x000002E3B88BC830>
# Vertices: 222
# Edges: 254

# %% [markdown]
# ## 8. Show the final result

# %%
Topology.Show(Graph.Reshape(graph, k=0.1),
              faceOpacity=0.1,
              sagitta=0,
              absolute=False,
              backgroundColor="white",
              vertexSize=15,
              vertexColorKey="color",
              edgeWidthKey="width",
              edgeColorKey="color",
              camera=[0,0,2],
              width=800,
              height=600,
              renderer=renderer)

# %% [markdown]
# ## 9. Use Pyvis for an alternative visualisation

# %%
pyvis_graph = Graph.PyvisGraph(graph, path=pyvis_file_path,
                               vertexSizeKey="size",
                               vertexColorKey="color",
                               vertexLabelKey="IFC_type",
                               edgeWeightKey="width",
                               edgeColorKey="color")
# Out:
# C:\Users\sarwj\OneDrive - Cardiff University\Desktop\pyvis_graph.html
